# %% [markdown]
# ## __Font Setting__

# %%
# -*- coding: utf-8 -*-
import matplotlib.font_manager as fm
import matplotlib
import pandas as pd
font_location='/usr/share/fonts/truetype/nanum/NanumGothicExtraBold.ttf'
font_name=fm.FontProperties(fname=font_location).get_name()
#print(font_name)
matplotlib.rc('font', family=font_name)
#matplotlib.matplotlib_fname()
company_name='포스코'
target_label='영업이익(손실)'

# %% [markdown]
# ## DART API connect

# %%
import dart_fss as dart
api_key='fcb0b5b6663759936ad3c7dbf488b1ead9459fd0'
dart.dart_set_api_key(api_key=api_key)
crp_list=dart.get_crp_list()

# %%
crp_list.find_by_name(company_name)
# Out:
# []

# %%
company_crp=crp_list.find_by_name(company_name)[0]

# %% [markdown]
# ## Download Reports from DART

# %%
#fs_annual = samsung_electronics.get_financial_statement(start_dt='20180101')

# %%
print(company_crp)
# Out:
# [096770]SK이노베이션

# %%
df = company_crp.get_financial_statement(start_dt='20120101')
# Out:
# Output()
# Output()
# HBox(children=(IntProgress(value=0, description='Annual reports', max=8, style=ProgressStyle(description_width…

# %%
#is 연결손익계산서, ci 연결포괄손익계산서
is_annual=df['is']

# %%
if (is_annual is None):
    is_annual=df['ci']

# %%
#with pd.option_context("display.max_rows", 1000):
display(is_annual)
# Out:
#    [D431410] Statement of comprehensive income, by function of expense - Consolidated financial statements (Unit: KRW)  \
#                                                                                                             concept_id
# 0                                        ifrs_Revenue
# 1                                    ifrs_CostOfSales
# 2                                    ifrs_GrossProfit
# 3      dart_TotalSellingGeneralAdministrativeExpenses
# 4                            dart_OperatingIncomeLoss
# 5   entity00631518_udf_IS_201931782714598_Statemen...
# 6   entity00631518_udf_IS_20193178271848_Statement...
# 7                                  ifrs_FinanceIncome
# 8                                   ifrs_FinanceCosts
# 9                                     dart_OtherGains
# 10  entity00631518_udf_IS_2018323183349647_Stateme...
# 11                                   dart_OtherLosses
# 12                           ifrs_ProfitLossBeforeTax
# 13          ifrs_IncomeTaxExpenseContinuingOperations
# 14            ifrs_ProfitLossFromContinuingOperations
# 15          ifrs_ProfitLossFromDiscontinuedOperations
# 16  entity00631518_udf_IS_201931820572156_Statemen...
# 17        ifrs_ProfitLossAttributableToOwnersOfParent
# 18  ifrs_ProfitLossAttributableToNoncontrollingInt...
# 19                      ifrs_OtherComprehensiveIncome
# 20  dart_OtherComprehensiveIncomeThatWillNotBeRecl...
# 21  entity00631518_udf_IS_20188715312978_OtherComp...
# 22  dart_OtherComprehensiveIncomeNetOfTaxGainsLoss...
# 23  dart_ShareOfOtherComprehensiveIncomeOfAssociat...
# 24  dart_OtherComprehensiveIncomeThatWillBeReclass...
# 25  ifrs_GainsLossesOnFinancialAssetsMeasuredAtFai...
# 26  ifrs_GainsLossesOnRemeasuringAvailableforsaleF...
# 27  dart_ShareOfOtherComprehensiveIncomeOfAssociat...
# 28  ifrs_GainsLossesOnExchangeDifferencesOnTransla...
# 29           ifrs_GainsLossesOnCashFlowHedgesNetOfTax
# 30                           ifrs_ComprehensiveIncome
# 31  ifrs_ComprehensiveIncomeAttributableToOwnersOf...
# 32  ifrs_ComprehensiveIncomeAttributableToNoncontr...
# 33                     ifrs_BasicEarningsLossPerShare
# 34  entity00631518_udf_IS_2018810145759209_Earning...
# 35  entity00631518_udf_IS_20188893132760_EarningsP...
# 36  entity00631518_udf_IS_2018810145826794_Earning...
#
#                                         \
#                               label_ko
# 0                                  매출액
# 1                                 매출원가
# 2                                매출총이익
# 3                              판매비와관리비
# 4                             영업이익(손실)
# 5                 금융수익-유효이자율법에 따른 이자수익
# 6                              금융수익-기타
# 7                                 금융수익
# 8                                 금융원가
# 9                                지분법손익
# 10                             기타영업외수익
# 11                             기타영업외비용
# 12                     법인세비용차감전순이익(손실)
# 13                     계속영업손익법인세비용(효익)
# 14                          계속영업이익(손실)
# 15                          중단영업이익(손실)
# 16                         연결당기순이익(손실)
# 17                           지배기업소유주지분
# 18                               비지배지분
# 19                            연결기타포괄손익
# 20             후속적으로 당기손익으로 재분류되지 않는항목
# 21               기타포괄손익-공정가치측정금융자산평가손익
# 22                       확정급여제도의 재측정요소
# 23                            해외사업환산손익
# 24           후속적으로 당기손익으로 재분류될 수 있는 항목
# 25  기타포괄손익-공정가치 측정 금융자산 평가손익(세후기타포괄손익)
# 26                          매도가능증권평가손익
# 27                             지분법자본변동
# 28                            해외사업환산손익
# 29                 현금흐름위험회피 파생금융상품평가손익
# 30                           연결당기총포괄이익
# 31                          지배기업 소유주지분
# 32                               비지배지분
# 33                       보통주기본주당이익(손실)
# 34                         구형우선주기본주당이익
# 35                       보통주기본주당계속영업이익
# 36                     구형우선주기본주당계속영업이익
#
#                                                                            \
#                                              label_en              class0
# 0                                               Sales  포괄손익계산서 [abstract]
# 1                                       Cost of sales  포괄손익계산서 [abstract]
# 2                                        Gross profit  포괄손익계산서 [abstract]
# 3             Selling general administrative expenses  포괄손익계산서 [abstract]
# 4                              Operating income(loss)  포괄손익계산서 [abstract]
# 5   Financial income - interest income calculated ...  포괄손익계산서 [abstract]
# 6                           Financial income - others  포괄손익계산서 [abstract]
# 7                                      Finance income  포괄손익계산서 [abstract]
# 8                                       Finance costs  포괄손익계산서 [abstract]
# 9                                         Other gains  포괄손익계산서 [abstract]
# 10                                      Other Incomes  포괄손익계산서 [abstract]
# 11                       Other non-operating expenses  포괄손익계산서 [abstract]
# 12                           Profit (loss) before tax  포괄손익계산서 [abstract]
# 13      Income tax expense from continuing operations  포괄손익계산서 [abstract]
# 14           Profit (loss) from continuing operations  포괄손익계산서 [abstract]
# 15                  Loss from discontinued operations  포괄손익계산서 [abstract]
# 16                                   Net Income(Loss)  포괄손익계산서 [abstract]
# 17    Profit (loss), attributable to owners of parent  포괄손익계산서 [abstract]
# 18  Profit (loss), attributable to non-controlling...  포괄손익계산서 [abstract]
# 19                    Other comprehensive profit/loss  포괄손익계산서 [abstract]
# 20  Other comprehensive income that will not be re...  포괄손익계산서 [abstract]
# 21  Net change in fair value of financial assets m...  포괄손익계산서 [abstract]
# 22  Other comprehensive income, net of tax, gains ...  포괄손익계산서 [abstract]
# 23  Share of other comprehensive income of associa...  포괄손익계산서 [abstract]
# 24  Other comprehensive income that will be reclas...  포괄손익계산서 [abstract]
# 25  Gains (losses) on financial assets measured at...  포괄손익계산서 [abstract]
# 26  Gains (losses) on remeasuring available-for-sa...  포괄손익계산서 [abstract]
# 27  Share of other comprehensive income of associa...  포괄손익계산서 [abstract]
# 28  Gains (losses) on exchange differences on tran...  포괄손익계산서 [abstract]
# 29     Gains (losses) on cash flow hedges, net of tax  포괄손익계산서 [abstract]
# 30                         Total comprehensive income  포괄손익계산서 [abstract]
# 31  Comprehensive income, attributable to owners o...  포괄손익계산서 [abstract]
# 32  Comprehensive income, attributable to non-cont...  포괄손익계산서 [abstract]
# 33                    Basic earnings (loss) per share  포괄손익계산서 [abstract]
# 34                            EPS for preferred stock  포괄손익계산서 [abstract]
# 35            Basic operating profit (loss) per share  포괄손익계산서 [abstract]
# 36                             OP for preferred stock  포괄손익계산서 [abstract]
#
#                                                      \
#                   class1                     class2
# 0                    매출액                       None
# 1                   매출원가                       None
# 2                  매출총이익                       None
# 3                판매비와관리비                       None
# 4               영업이익(손실)                       None
# 5   금융수익-유효이자율법에 따른 이자수익                       None
# 6                금융수익-기타                       None
# 7                   금융수익                       None
# 8                   금융원가                       None
# 9                  지분법손익                       None
# 10               기타영업외수익                       None
# 11               기타영업외비용                       None
# 12       법인세비용차감전순이익(손실)                       None
# 13       계속영업손익법인세비용(효익)                       None
# 14            계속영업이익(손실)                       None
# 15            중단영업이익(손실)                       None
# 16           연결당기순이익(손실)                       None
# 17       연결당기순이익(손실)의 귀속                  지배기업소유주지분
# 18       연결당기순이익(손실)의 귀속                      비지배지분
# 19              연결기타포괄손익                       None
# 20              연결기타포괄손익    후속적으로 당기손익으로 재분류되지 않는항목
# 21              연결기타포괄손익    후속적으로 당기손익으로 재분류되지 않는항목
# 22              연결기타포괄손익    후속적으로 당기손익으로 재분류되지 않는항목
# 23              연결기타포괄손익    후속적으로 당기손익으로 재분류되지 않는항목
# 24              연결기타포괄손익  후속적으로 당기손익으로 재분류될 수 있는 항목
# 25              연결기타포괄손익  후속적으로 당기손익으로 재분류될 수 있는 항목
# 26              연결기타포괄손익  후속적으로 당기손익으로 재분류될 수 있는 항목
# 27              연결기타포괄손익  후속적으로 당기손익으로 재분류될 수 있는 항목
# 28              연결기타포괄손익  후속적으로 당기손익으로 재분류될 수 있는 항목
# 29              연결기타포괄손익  후속적으로 당기손익으로 재분류될 수 있는 항목
# 30             연결당기총포괄이익                       None
# 31          연결당기포괄손익의 귀속                 지배기업 소유주지분
# 32          연결당기포괄손익의 귀속                      비지배지분
# 33       주당이익 [abstract]              보통주기본주당이익(손실)
# 34       주당이익 [abstract]                구형우선주기본주당이익
# 35       주당이익 [abstract]              보통주기본주당계속영업이익
# 36       주당이익 [abstract]            구형우선주기본주당계속영업이익
#
#                                           20180101-20181231  \
#                                 class3            (연결재무제표,)
# 0                                 None 54,510,898,386,000.0
# 1                                 None 50,529,216,158,000.0
# 2                                 None  3,981,682,228,000.0
# 3                                 None  1,864,092,438,000.0
# 4                                 None  2,117,589,790,000.0
# 5                                 None     40,226,278,000.0
# 6                                 None  3,141,034,659,000.0
# 7                                 None                  0.0
# 8                                 None  2,949,103,372,000.0
# 33                                       nan                  nan
# 34                                       nan                  nan
# 35                                       nan                  nan
# 36                                       nan                  nan
#
#       20110101-20111231    20100101-20101231
#               (연결재무제표,)            (연결재무제표,)
# 0  68,371,154,904,000.0 53,722,460,830,000.0
# 1  63,551,358,203,000.0 49,749,440,861,000.0
# 2   4,819,796,701,000.0  3,973,019,969,000.0
# 3   1,860,313,728,000.0  1,705,222,130,000.0
# 4   2,959,482,973,000.0  1,891,155,356,000.0
# 5                   nan                  nan
# 6                   nan                  nan
# 7   2,704,798,348,000.0    855,598,989,000.0
# 8   2,736,881,053,000.0  1,266,124,913,000.0
# 9     106,228,666,000.0                  nan
# 10  2,191,142,820,000.0     58,603,097,000.0
# 11    916,124,206,000.0     36,812,045,000.0
# 12  4,308,647,548,000.0  1,502,420,484,000.0
# 13                  nan                  nan
# 14                  nan                  nan
# 15                  nan                  nan
# 16  3,175,843,551,000.0  1,149,181,601,000.0
# 17  3,169,007,793,000.0  1,138,752,268,000.0
# 18      6,835,758,000.0     10,429,333,000.0
# 19    166,274,593,000.0     -3,178,298,000.0
# 20    -28,598,145,000.0    -13,917,224,000.0
# 21                  nan                  nan
# 22                  nan                  nan
# 23     33,256,540,000.0     10,354,059,000.0
# 24                  nan                  nan
# 25                  nan                  nan
# 26    -12,162,441,000.0     38,832,084,000.0
# 27    438,529,162,000.0    -15,808,369,000.0
# 28                  nan                  nan
# 29     -1,721,812,000.0        332,832,000.0
# 30  3,342,118,144,000.0  1,146,003,303,000.0
# 31  3,322,953,558,000.0  1,136,887,770,000.0
# 32     19,164,586,000.0      9,115,533,000.0
# 33                  nan                  nan
# 34                  nan                  nan
# 35                  nan                  nan
# 36                  nan                  nan

# %% [markdown]
# ## Get '영업손실' Index

# %%
try:
    check_table=is_annual.iloc[:,1]==target_label
    index=check_table[check_table].index[0]
except IndexError:
    target_label='영업이익(손실)'
    check_table=is_annual.iloc[:,1]==target_label
    index=check_table[check_table].index[0]

# %% [markdown]
# ## Get Years' Value Stored Location

# %%
column_index=0
for tuple_column in is_annual.columns:
    if tuple_column[0].startswith('2'):
        break
    column_index=column_index+1

# %% [markdown]
# ## Get Area Interested in

# %%
is_annual_modi=is_annual.iloc[index][column_index:]
#is_annual_modi.index

# %% [markdown]
# ## Result series index modification

# %%
index_array=[]
for tu in is_annual_modi.index:
    index_array.append(tu[0])

is_annual_modi.index=index_array

# %% [markdown]
# ## string result convert to integer value

# %%
is_annual_modi
is_annual_modi=is_annual_modi.dropna()

is_annual_modi=pd.to_numeric(is_annual_modi)
is_annual_modi=is_annual_modi.dropna()

# %% [markdown]
# ## Unit Change from '원' to '조'

# %%
is_annual_modi=is_annual_modi[:]/1000000000000

# %% [markdown]
# ## Draw Graph

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.plot(is_annual_modi)
plt.xlabel('년도')
plt.ylabel('조')
plt.grid(True)
plt.xticks(size=9)

#is_annual_modi.plot(kind='line', title='test',figsize=(15,10) )
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8], <a list of 9 Text xticklabel objects>)
